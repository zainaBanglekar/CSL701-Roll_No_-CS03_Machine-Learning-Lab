# %% [markdown]
# <a href="https://colab.research.google.com/github/zainaBanglekar/CSL701-Roll_No_-CS03_Machine-Learning-Lab/blob/main/Experiments%20and%20Mini-Project/Practical01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61298cbf-20a2-4f0f-80ad-04ed0d0267e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61298cbf-20a2-4f0f-80ad-04ed0d0267e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ==========================================
# Phase 2: Environment Setup & Data Loading
# ==========================================

# Task 1: Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Task 2: Load train.csv
df = pd.read_csv("Titanic-Dataset.csv")

# ==========================================
# Phase 3: Data Inspection
# ==========================================

# Task 3: Display first 10 rows
print("First 10 Rows:")
print(df.head(10))

# Task 4: Display last 5 rows
print("\nLast 5 Rows:")
print(df.tail(5))

# Task 5: Check dataset dimensions
print("\nDataset Shape:")
print(df.shape)        # Expected: (891, 12)

# Task 6: Display dataset information
print("\nDataset Information:")
print(df.info())

# Task 7: Summary statistics
print("\nSummary Statistics:")
print(df.describe())

print("\nAge Statistics")
print("Mean Age:", df["Age"].mean())
print("Minimum Age:", df["Age"].min())
print("Maximum Age:", df["Age"].max())

print("\nFare Statistics")
print("Mean Fare:", df["Fare"].mean())
print("Minimum Fare:", df["Fare"].min())
print("Maximum Fare:", df["Fare"].max())

# Task 8: Identify missing values
print("\nMissing Values:")
print(df.isnull().sum())

# ==========================================
# Phase 4: Data Manipulation & Cleaning
# ==========================================

# Task 9: Fill missing Age values with median
df["Age"].fillna(df["Age"].median(), inplace=True)

# Task 10: Filter surviving passengers
survivors = df[df["Survived"] == 1]

print("\nNumber of Survivors:", len(survivors))

# Task 11: Convert Fare column to NumPy array
fare_array = df["Fare"].to_numpy()

print("\nFare NumPy Array:")
print(fare_array)

# Task 12: Calculate maximum and average Fare
print("\nMaximum Fare:", np.max(fare_array))
print("Average Fare:", np.mean(fare_array))

# ==========================================
# Phase 5: Data Visualization
# ==========================================

# Task 13: Histogram of Age
plt.figure(figsize=(6,4))
plt.hist(df["Age"], bins=20, color="skyblue", edgecolor="black")
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Task 14: Bar Chart of Survival Count
plt.figure(figsize=(5,4))
sns.countplot(x="Survived", data=df, palette="Set2")
plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# Task 15: Scatter Plot of Age vs Fare
plt.figure(figsize=(6,4))
plt.scatter(df["Age"], df["Fare"], color="red", alpha=0.6)
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()
# Out:
# First 10 Rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...
